# %% [markdown]
# # Step 1: Data Inspection
# Loading the Building Data Genome 2 dataset and inspecting its structure.

# %%
import pandas as pd
import sys
import os

# Add project root to path to import src modules
current_dir = os.getcwd()
project_root = os.path.dirname(current_dir)
sys.path.append(project_root)

from src.data_loader import load_data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 10
#       7 project_root = os.path.dirname(current_dir)
#       8 sys.path.append(project_root)
# ---> 10 from src.data_loader import load_data
#
# File e:\CODING\New folder\src\data_loader.py:6
#       3 import os
#       4 from src.utils import setup_logger
# ----> 6 logger = setup_logger()
#       8 def load_data(data_path):
#       9     """
#      10     Loads and merges CSV files from the specified directory recursively.
#      11
#    (...)     16         pd.DataFrame: Merged dataframe containing data from all found CSV files.
#      17     """
#
# File e:\CODING\New folder\src\utils.py:13, in setup_logger(name, log_file)
#      11 # Create handlers
#      12 c_handler = logging.StreamHandler()
# ---> 13 f_handler = logging.FileHandler(log_file)
#      14 c_handler.setLevel(logging.INFO)
#      15 f_handler.setLevel(logging.INFO)
#
# File e:\CODING\System\Anaconda\Lib\logging\__init__.py:1219, in FileHandler.__init__(self, filename, mode, encoding, delay, errors)
#    1217     self.stream = None
#    1218 else:
# -> 1219     StreamHandler.__init__(self, self._open())
#
# File e:\CODING\System\Anaconda\Lib\logging\__init__.py:1248, in FileHandler._open(self)
#    1243 """
#    1244 Open the current base file with the (original) mode and encoding.
#    1245 Return the resulting stream.
#    1246 """
#    1247 open_func = self._builtin_open
# -> 1248 return open_func(self.baseFilename, self.mode,
#    1249                  encoding=self.encoding, errors=self.errors)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'e:\\CODING\\New folder\\notebooks\\results\\project.log'

# %%
# Load data
# Adjust path as needed based on where the notebook is running
data_path = os.path.join(project_root, 'data')
df = load_data(data_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Load data
#       2 # Adjust path as needed based on where the notebook is running
#       3 data_path = os.path.join(project_root, 'data')
# ----> 4 df = load_data(data_path)
#
# NameError: name 'load_data' is not defined

# %%
print("Shape:", df.shape)
print(df.info())
display(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print("Shape:", df.shape)
#       2 print(df.info())
#       3 display(df.head())
#
# NameError: name 'df' is not defined

# %%
display(df.describe())

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()
